# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %%
start_year = '1952'
end_year = '2020'

base_link = 'https://www.weltfussball.de/spielplan/dfb-pokal-'
end_link = '/3/'

links = []
seasons = []

season_dic = {
    'SeasonStart': '',
    'SeasonEnd': '',
    
    'DFB_link1':'',
    'DFB_link2':'',
    'DFB_link3':'',
    'DFB_link4':'',
    'DFB_link5':'',
    'DFB_link6':''
}

link = 'https://www.weltfussball.de/spielplan/dfb-pokal-2020-2021-1-runde/0/'

for year in range(int(start_year), 1955):
    season_dic = {
        'SeasonStart': '',
        'SeasonEnd': '',

        'DFB_link1':'',
        'DFB_link2':'',
        'DFB_link3':'',
        'DFB_link4':'',
        'DFB_link5':'',
        'DFB_link6':''
    }
    
    season_dic['SeasonStart'] = year
    season_dic['SeasonEnd'] = year + 1
    
    season_dic['DFB_link1'] = base_link + str(year) + '-'+ str(year+1) + '-1-runde'+ end_link
    season_dic['DFB_link2'] = base_link + str(year) + '-'+ str(year+1) + '-2-runde'+ end_link
    season_dic['DFB_link3'] = base_link + str(year) + '-'+ str(year+1) + '-achtelfinale'+ end_link
    season_dic['DFB_link4'] = base_link + str(year) + '-'+ str(year+1) + '-viertelfinale'+ end_link
    season_dic['DFB_link5'] = base_link + str(year) + '-'+ str(year+1) + '-halbfinale'+ end_link
    season_dic['DFB_link6'] = base_link + str(year) + '-'+ str(year+1) + '-endspiel'+ end_link
    
    seasons.append(season_dic)
    #print(season_dic['SeasonStart'])
    #print(season_dic['SeasonEnd'])
    #print()
    
print(seasons[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/s4/309fk8t94hn1mrnxyf1l3b580000gn/T/ipykernel_22153/2578919865.py in <module>
#      33     season_dic['DFB_link6'] = base_link + str(year) + '-'+ str(year+1) + '-endspiel'+ end_link
#      34
# ---> 35     seasons = seasons.append(season_dic)
#      36     #print(season_dic['SeasonStart'])
#      37     #print(season_dic['SeasonEnd'])
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %%
data = pd.DataFrame({'Date': [], 'Home':[], 'Away': [], 'Result':[]})

# %%
for season in seasons:
    links = [season['DFB_link1'],season['DFB_link2'],season['DFB_link3'],season['DFB_link4'],season['DFB_link5'],season['DFB_link6']]
    
    for link in links:
        html = requests.get(link).text
        soup = bs(html, 'html.parser')

        # get whole table
        table = soup.find('table', class_='standard_tabelle')

        # tablerow
        tr = table.find_all('tr')

        date = ''

        for r in tr:
            try:
                temp_date = r.find('td', nowrap='nowrap').text
                if temp_date != '':
                    date = temp_date
                #print(date.text)
            except:
                pass

            try:
                match = r.find_all('a')
                home = match[0].text
                away = match[1].text
                result = match[2].text
            except:
                pass

            temp_df = pd.DataFrame({'Date': [date], 'Home':[home], 'Away': [away], 'Result':[result]})
            data = data.append(temp_df)
            print(f'{date},{home},{away},{result}')
    print()

print('Fertig')
# Out:
# 02.08.1954,SG Düren 99,1. FC Kaiserslautern,2:5 (0:2)
# 19.12.1954,TuS Bremerhaven 93,Hamburger SV,3:1 (1:0)
# 19.12.1954,TuS Bremerhaven 93,Hamburger SV,3:1 (1:0)
# 17.10.1954,1. FC Schweinfurt 05,FC Schalke 04,0:1 (0:0)
# 27.11.1954,VfB Stuttgart,Karlsruher SC,2:5 (1:4)
# 19.12.1954,Altona 93,Alemannia Aachen,2:0 (0:0)
# 02.01.1955,Kickers Offenbach,1. FC Kaiserslautern,4:1 (2:0)
# 02.01.1955,FC Schalke 04,TuS Bremerhaven 93,2:0 (0:0)
# 07.04.1955,FC Schalke 04,Kickers Offenbach,2:1 (1:1)
# 20.04.1955,Altona 93,Karlsruher SC,3:3 (2:0, 3:3) n.V.
# 20.04.1955,Altona 93,Karlsruher SC,3:3 (2:0, 3:3) n.V.
# 08.05.1955,Karlsruher SC,Altona 93,3:0 (0:0)
# 21.05.1955,Karlsruher SC,FC Schalke 04,3:2 (1:1)
#
# Fertig

# %%
for link in links:
    html = requests.get(link).text
    soup = bs(html, 'html.parser')

    # get whole table
    table = soup.find('table', class_='standard_tabelle')

    # tablerow
    tr = table.find_all('tr')

    date = ''

    for r in tr:
        try:
            temp_date = r.find('td', nowrap='nowrap').text
            if temp_date != '':
                date = temp_date
            #print(date.text)
        except:
            pass

        try:
            match = r.find_all('a')
            home = match[0].text
            away = match[1].text
            result = match[2].text
        except:
            pass
        
        temp_df = pd.DataFrame({'Date': [date], 'Home':[home], 'Away': [away], 'Result':[result]})
        data = data.append(temp_df)
        print(f'{date},{home},{away},{result}')

print('Fertig')
# Out:
# Fertig

# %%
data
# Out:
#           Date               Home                  Away               Result
# 0   02.08.1954        SG Düren 99  1. FC Kaiserslautern           2:5 (0:2)
# 0   15.08.1954  Kickers Offenbach           Hannover 96           6:3 (2:2)
# 0   15.08.1954      VfB Stuttgart      Arminia Hannover           4:2 (0:1)
# 0   15.08.1954       Hamburger SV       Eintracht Trier  5:3 (2:1, 3:3) n.V.
# 0   15.08.1954     1. FC Nürnberg         TSV Marl-Hüls           2:0 (2:0)
# ..         ...                ...                   ...                  ...
# 0   07.04.1955      FC Schalke 04     Kickers Offenbach           2:1 (1:1)
# 0   20.04.1955          Altona 93         Karlsruher SC  3:3 (2:0, 3:3) n.V.
# 0   20.04.1955          Altona 93         Karlsruher SC  3:3 (2:0, 3:3) n.V.
# 0   08.05.1955      Karlsruher SC             Altona 93           3:0 (0:0)
# 0   21.05.1955      Karlsruher SC         FC Schalke 04           3:2 (1:1)
#
# [291 rows x 4 columns]

# %%
dic = {
    'SeasonStart': '1950',
    'SeasonEnd': '1951',
    'SeasonLink': ''
}

dic2 = {
    'SeasonStart': '1958',
    'SeasonEnd': '1951',
    'SeasonLink': ''
}

seasons = []
seasons.append(dic)
seasons.append(dic2)

for season in seasons:
    print(season['SeasonStart'])
# Out:
# 1950
# 1958
