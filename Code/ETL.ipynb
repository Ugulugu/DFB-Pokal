# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %%
start_year = '1952'
end_year = '2020'

base_link = 'https://www.weltfussball.de/spielplan/dfb-pokal-'
end_link = '/3/'

links = []
seasons = []


for year in range(int(start_year), 1960):
    season_dic = {
        'SeasonStart': '',
        'SeasonEnd': '',
        

        'DFB_link1':'',
        'DFB_link2':'',
        'DFB_link3':'',
        'DFB_link4':'',
        'DFB_link5':'',
        'DFB_link6':''
    }
    
    season_dic['SeasonStart'] = year
    season_dic['SeasonEnd'] = year + 1
    
    season_dic['DFB_link1'] = base_link + str(year) + '-'+ str(year+1) + '-1-runde'+ end_link
    season_dic['DFB_link2'] = base_link + str(year) + '-'+ str(year+1) + '-2-runde'+ end_link
    season_dic['DFB_link3'] = base_link + str(year) + '-'+ str(year+1) + '-achtelfinale'+ end_link
    season_dic['DFB_link4'] = base_link + str(year) + '-'+ str(year+1) + '-viertelfinale'+ end_link
    season_dic['DFB_link5'] = base_link + str(year) + '-'+ str(year+1) + '-halbfinale'+ end_link
    season_dic['DFB_link6'] = base_link + str(year) + '-'+ str(year+1) + '-endspiel'+ end_link
    
    seasons.append(season_dic)
    #print(season_dic['SeasonStart'])
    #print(season_dic['SeasonEnd'])
    #print()
    
for season in seasons:
    print(season)
    print()
# Out:
# {'SeasonStart': 1952, 'SeasonEnd': 1953, 'DFB_link1': 'https://www.weltfussball.de/spielplan/dfb-pokal-1952-1953-1-runde/3/', 'DFB_link2': 'https://www.weltfussball.de/spielplan/dfb-pokal-1952-1953-2-runde/3/', 'DFB_link3': 'https://www.weltfussball.de/spielplan/dfb-pokal-1952-1953-achtelfinale/3/', 'DFB_link4': 'https://www.weltfussball.de/spielplan/dfb-pokal-1952-1953-viertelfinale/3/', 'DFB_link5': 'https://www.weltfussball.de/spielplan/dfb-pokal-1952-1953-halbfinale/3/', 'DFB_link6': 'https://www.weltfussball.de/spielplan/dfb-pokal-1952-1953-endspiel/3/'}
#
# {'SeasonStart': 1953, 'SeasonEnd': 1954, 'DFB_link1': 'https://www.weltfussball.de/spielplan/dfb-pokal-1953-1954-1-runde/3/', 'DFB_link2': 'https://www.weltfussball.de/spielplan/dfb-pokal-1953-1954-2-runde/3/', 'DFB_link3': 'https://www.weltfussball.de/spielplan/dfb-pokal-1953-1954-achtelfinale/3/', 'DFB_link4': 'https://www.weltfussball.de/spielplan/dfb-pokal-1953-1954-viertelfinale/3/', 'DFB_link5': 'https://www.weltfussball.de/spielplan/dfb-pokal-1953-1954-halbfinale/3/', 'DFB_link6': 'https://www.weltfussball.de/spielplan/dfb-pokal-1953-1954-endspiel/3/'}
#
# {'SeasonStart': 1954, 'SeasonEnd': 1955, 'DFB_link1': 'https://www.weltfussball.de/spielplan/dfb-pokal-1954-1955-1-runde/3/', 'DFB_link2': 'https://www.weltfussball.de/spielplan/dfb-pokal-1954-1955-2-runde/3/', 'DFB_link3': 'https://www.weltfussball.de/spielplan/dfb-pokal-1954-1955-achtelfinale/3/', 'DFB_link4': 'https://www.weltfussball.de/spielplan/dfb-pokal-1954-1955-viertelfinale/3/', 'DFB_link5': 'https://www.weltfussball.de/spielplan/dfb-pokal-1954-1955-halbfinale/3/', 'DFB_link6': 'https://www.weltfussball.de/spielplan/dfb-pokal-1954-1955-endspiel/3/'}
#
# {'SeasonStart': 1959, 'SeasonEnd': 1960, 'DFB_link1': 'https://www.weltfussball.de/spielplan/dfb-pokal-1959-1960-1-runde/3/', 'DFB_link2': 'https://www.weltfussball.de/spielplan/dfb-pokal-1959-1960-2-runde/3/', 'DFB_link3': 'https://www.weltfussball.de/spielplan/dfb-pokal-1959-1960-achtelfinale/3/', 'DFB_link4': 'https://www.weltfussball.de/spielplan/dfb-pokal-1959-1960-viertelfinale/3/', 'DFB_link5': 'https://www.weltfussball.de/spielplan/dfb-pokal-1959-1960-halbfinale/3/', 'DFB_link6': 'https://www.weltfussball.de/spielplan/dfb-pokal-1959-1960-endspiel/3/'}

# %%
data = pd.DataFrame({'Date': [], 'Leg': [], 'Home':[], 'Away': [], 'Result':[]})

for season in seasons:
    links = [season['DFB_link1'],season['DFB_link2'],season['DFB_link3'],season['DFB_link4'],season['DFB_link5'],season['DFB_link6']]
    
    for link in links:
        html = requests.get(link).text
        soup = bs(html, 'html.parser')

        # get whole table
        table = soup.find('table', class_='standard_tabelle')

        # tablerow
        tr = table.find_all('tr')

        date = ''

        for r in tr:
            try:
                temp_date = r.find('td', nowrap='nowrap').text
                if temp_date != '':
                    date = temp_date
                #print(date.text)
            except:
                pass

            try:
                leg = soup.title.text
                match = r.find_all('a')
                home = match[0].text
                away = match[1].text
                result = match[2].text
            except:
                pass

            temp_df = pd.DataFrame({'Date': [date], 'Leg': [leg], 'Home':[home], 'Away': [away], 'Result':[result]})
            data = data.append(temp_df)
        print(f'Done with: {leg}')
    print()

print('Fertig')
# Out:
# Done with: DFB-Pokal 1952/1953 » 1. Runde
# Done with: weltfussball.de
# Done with: DFB-Pokal 1952/1953 » Achtelfinale
# Done with: DFB-Pokal 1952/1953 » Viertelfinale
# Done with: DFB-Pokal 1952/1953 » Halbfinale
# Done with: DFB-Pokal 1952/1953 » Finale
#
# Done with: weltfussball.de
# Done with: weltfussball.de
# Done with: weltfussball.de
# Done with: DFB-Pokal 1953/1954 » Viertelfinale
# Done with: DFB-Pokal 1953/1954 » Halbfinale
# Done with: DFB-Pokal 1953/1954 » Finale
#
# Done with: DFB-Pokal 1954/1955 » 1. Runde
# Done with: weltfussball.de
# Done with: DFB-Pokal 1954/1955 » Achtelfinale
# Done with: DFB-Pokal 1954/1955 » Viertelfinale
# Done with: DFB-Pokal 1954/1955 » Halbfinale
# Done with: DFB-Pokal 1954/1955 » Finale
#
# Done with: weltfussball.de
# Done with: weltfussball.de
# Done with: weltfussball.de
# Done with: weltfussball.de
# Done with: DFB-Pokal 1955/1956 » Halbfinale
# Done with: DFB-Pokal 1955/1956 » Finale
#
# Done with: weltfussball.de
# Done with: weltfussball.de
# Done with: weltfussball.de
# Done with: weltfussball.de
# Done with: DFB-Pokal 1956/1957 » Halbfinale
# Done with: DFB-Pokal 1956/1957 » Finale
#
# Done with: weltfussball.de
# Done with: weltfussball.de
# Done with: weltfussball.de
# Done with: weltfussball.de
# Done with: DFB-Pokal 1957/1958 » Halbfinale
# Done with: DFB-Pokal 1957/1958 » Finale
#
# Done with: weltfussball.de
# Done with: weltfussball.de
# Done with: weltfussball.de
# Done with: weltfussball.de
# Done with: DFB-Pokal 1958/1959 » Halbfinale
# Done with: DFB-Pokal 1958/1959 » Finale
#
# Done with: weltfussball.de
# Done with: weltfussball.de
# Done with: weltfussball.de
# Done with: weltfussball.de
# Done with: DFB-Pokal 1959/1960 » Halbfinale
# Done with: DFB-Pokal 1959/1960 » Finale
#
# Fertig

# %%
data.to_csv('Data.csv')
